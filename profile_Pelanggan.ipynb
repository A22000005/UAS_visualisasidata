# %% [markdown]
# <a href="https://colab.research.google.com/github/A22000005/UAS_visualisasidata/blob/main/profile_Pelanggan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('profile_pelanggan.csv')

# %%
print(df)
# Out:
#        data     provinsi
# 0     15572  DKI Jakarta
# 1     12461   Jawa Timur
# 2     12590   Jawa Barat
# 3     16839  DKI Jakarta
# 4     13596  DKI Jakarta
# ...     ...          ...
# 2353  18261  DKI Jakarta
# 2354  18257  DKI Jakarta
# 2355  12510  Jawa Tengah
# 2356  16198  DKI Jakarta
# 2357  16235  DKI Jakarta
#
# [2358 rows x 2 columns]

# %%
x=df['data']
y=df['provinsi']

plt.figure(figsize=(10, 8))
plt.scatter(x,y)

plt.title('Scater Plot Profile Pelanggan')

plt.show()
